# %%
import pandas as pd
from conexao_banco import conexao_aws
import os

# %%
usuario_sql = os.getenv('usuario_sql')
senha_sql = os.getenv('senha_sql')
aws = conexao_aws(senha=senha_sql, usuario=usuario_sql, nome_do_banco='varos_dashs')
aws.iniciar_conexao()

# %%
dataframe = pd.read_csv("close.csv")
dataframe
# Out:
#            Date  ABEV3.SA   ALPA4.SA   ALSO3.SA   ARZZ3.SA  ASAI3.SA  \
# 0    2021-03-19     15.60  35.779999  26.820000  72.830002    14.268
# 1    2021-03-22     15.54  36.049999  26.719999  72.330002    14.000
# 2    2021-03-23     15.08  36.230000  26.950001  73.430000    14.156
# 3    2021-03-24     14.80  34.669998  26.469999  69.080002    13.700
# 4    2021-03-25     14.99  36.250000  26.820000  69.830002    14.374
# ..          ...       ...        ...        ...        ...       ...
# 515  2023-04-10     14.46   7.820000  17.840000  63.590000    13.920
# 516  2023-04-11     14.78   8.230000  18.290001  69.000000    14.710
# 517  2023-04-12     14.76   8.170000  18.350000  68.910004    14.440
# 518  2023-04-13     14.59   8.000000  18.629999  68.870003    13.750
# 519  2023-04-14     14.65   7.590000  18.620001  67.860001    13.220
#
#       AZUL4.SA   B3SA3.SA   BBAS3.SA   BBDC3.SA  ...   TOTS3.SA   UGPA3.SA  \
# ...

# %%
df_melted = pd.melt(dataframe, id_vars="Date", var_name='Ticker', value_name='Price')
df_melted.to_sql("dash_fechamento_curso", con=aws.engine)
# Out:
# 46280
